# %%
import matplotlib.pyplot as plt

import sys
sys.path.append("..")

# %%
from data_normalization import data_normalization
df = data_normalization("../data/personality_dataset.csv")

df.head()
# Out:
#    Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 0               4.0           0                      4.0            6.0
# 1               9.0           1                      0.0            0.0
# 2               9.0           1                      1.0            2.0
# 3               0.0           0                      6.0            7.0
# 4               3.0           0                      9.0            4.0
#
#    Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                          0                 13.0             5.0   Extrovert
# 1                          1                  0.0             3.0   Introvert
# 2                          1                  5.0             2.0   Introvert
# 3                          0                 14.0             8.0   Extrovert
# 4                          0                  8.0             5.0   Extrovert

# %% [markdown]
# # Introverts vs. extroverts
# Here we will compare and explore different aspects of the personality types. We will first check the distribution between the types.

# %%
# Count number of introverts and extroverts
personality_counts = df["Personality"].value_counts()

# %% [markdown]
# We will then visualize how many extroverts there are compared to introverts.

# %%
# Plot it
plt.figure(figsize=(6,4))
personality_counts.plot(kind="bar")
plt.title("Amount of extroverts vs. introverts")
plt.xlabel("Personality Type")
plt.ylabel("Amount")
plt.xticks(rotation=0)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Social events and going outside
# Here we will compare how much introverts and extrovert go out and attend social events.

# %%
# Group by personality, and sum the values for social activity
out_and_events = df.groupby("Personality")[["Social_event_attendance", "Going_outside"]].sum()
out_and_events
# Out:
# C:\Users\odary\AppData\Local\Temp\ipykernel_16408\2154604384.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   out_and_events = df.groupby("Personality")[["Social_event_attendance", "Going_outside"]].sum()
#              Social_event_attendance  Going_outside
# Personality
# Extrovert                8912.973925         6853.0
# Introvert                2580.754052         1847.0

# %% [markdown]
# We can see extroverts indeed go out and attend events considerably more often than introverts. Let's visualize this:

# %%
# Plot the chart
out_and_events.plot(kind="bar", figsize=(8,5))
plt.title("Social activity: extroverts vs. introverts")
plt.xticks(rotation=0)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.legend(title="Activity type")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Amount of friends

# %%
# Calculate average of friends
avg_friends = df.groupby("Personality")["Friends_circle_size"].mean().round(2)
avg_friends
# Out:
# C:\Users\odary\AppData\Local\Temp\ipykernel_16408\1090555320.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_friends = df.groupby("Personality")["Friends_circle_size"].mean().round(2)
# Personality
# Extrovert    9.10
# Introvert    3.28
# Name: Friends_circle_size, dtype: float64

# %% [markdown]
# # Outliers and anomalies
